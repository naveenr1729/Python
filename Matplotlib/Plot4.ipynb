# %% [markdown]
# <h1 align="center"><font color="#fffff7">3D Plotting in Matplotlib</h1>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 3D Scatter plot

# %%
d1=pd.read_csv(r"D:\VS code\Datasets\batter.csv")
d1
# Out:
#              batter  runs        avg  strike_rate
# 0           V Kohli  6634  36.251366   125.977972
# 1          S Dhawan  6244  34.882682   122.840842
# 2         DA Warner  5883  41.429577   136.401577
# 3         RG Sharma  5881  30.314433   126.964594
# 4          SK Raina  5536  32.374269   132.535312
# ..              ...   ...        ...          ...
# 600         C Nanda     0   0.000000     0.000000
# 601      Akash Deep     0   0.000000     0.000000
# 602         S Ladda     0   0.000000     0.000000
# 603  V Pratap Singh     0   0.000000     0.000000
# 604    S Lamichhane     0   0.000000     0.000000
#
# [605 rows x 4 columns]

# %%
fig=plt.figure(figsize=(15,8))
ax=plt.subplot(projection="3d")

ax.scatter3D(d1["runs"],d1["avg"],d1["strike_rate"])
ax.set_title("Performance Analysis")
ax.set_xlabel("Runs")
ax.set_ylabel("Avg")
ax.set_zlabel("Strike Rate")
# Out:
# Text(0.5, 0, 'Strike Rate')

# %% [markdown]
# # 3d Line plot

# %%
x=[0,1,5,24]
y=[0,10,13,75]
z=[0,13,20,43]

fig=plt.figure()
ax=plt.subplot(projection="3d")

ax.scatter3D(x,y,z,s=[100,100,100,100])
ax.plot3D(x,y,z)

# %% [markdown]
# # 3D Surface Plots

# %%
x=np.linspace(-10,10,100)
y=np.linspace(-10,10,100)

# %%
xx,yy=np.meshgrid(x,y)

# %%
z=xx**2+yy**2
z.shape
# Out:
# (100, 100)

# %%
fig=plt.figure(figsize=(12,6))
ax=plt.subplot(projection="3d")

p=ax.plot_surface(xx,yy,z,cmap="viridis")
fig.colorbar(p)

# %%
z=np.sin(xx)+np.cos(yy)

# %%
fig=plt.figure(figsize=(12,6))
ax=plt.subplot(projection="3d")

p=ax.plot_surface(xx,yy,z,cmap="viridis")
fig.colorbar(p)

# %% [markdown]
# # Contour Plot
# * Converts 3D surface plot into 2D.

# %%
z=xx**2+yy**2

# %%
fig=plt.figure(figsize=(9,5))
ax=plt.subplot()

p=ax.contour(xx,yy,z,cmap="viridis")
fig.colorbar(p)

# %%
fig=plt.figure()
ax=plt.subplot()

p=ax.contourf(xx,yy,z)
fig.colorbar(p)

# %%
z=np.sin(xx)+np.cos(yy)

# %%
fig=plt.figure()
ax=plt.subplot()

p=ax.contourf(xx,yy,z)
fig.colorbar(p)

# %% [markdown]
# # Heatmap

# %%
d2=pd.read_csv(r"D:\VS code\Datasets\IPL_Ball_by_Ball_2008_2022.csv")
d2
# Out:
#              ID  innings  overs  ballnumber       batter          bowler  \
# 0       1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1       1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2       1312200        1      0           3   JC Buttler  Mohammed Shami
# 3       1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4       1312200        1      0           5  YBK Jaiswal  Mohammed Shami
# ...         ...      ...    ...         ...          ...             ...
# 225949   335982        2     14           5      P Kumar        I Sharma
# 225950   335982        2     14           6     SB Joshi        I Sharma
# 225951   335982        2     14           7      P Kumar        I Sharma
# 225952   335982        2     15           1     SB Joshi       LR Shukla
# 225953   335982        2     15           2     SB Joshi       LR Shukla
#
#         non-striker extra_type  batsman_run  extras_run  total_run  \
# ...

# %%
temp_d2=d2[(d2["ballnumber"].isin([1,2,3,4,5,6])) & (d2["batsman_run"]==6)]

# %%
grid=temp_d2.pivot_table(index="overs",columns="ballnumber",values="batsman_run",aggfunc='count')
grid
# Out:
# ballnumber    1    2    3    4    5    6
# overs
# 0             9   17   31   39   33   27
# 1            31   40   49   56   58   54
# 2            75   62   70   72   58   76
# 3            60   74   74  103   74   71
# 4            71   76  112   80   81   72
# 5            77  102   63   86   78   80
# 6            34   56   49   59   64   38
# 7            59   62   73   70   69   56
# 8            86   83   79   81   73   52
# 9            54   62   86   61   74   67
# 10           82   92   83   69   72   70
# 11           91   72   87   79   87   70
# 12           87  109   79  100  100   84
# 13          101  101   99   97   90   88
# 14           90  124  103  100   86  106
# 15          102  120  129  121  113   96
# 16          107  115  111  100  120  101
# 17          126  142  137  151  117  129
# 18          118  114  151  132  138  128
# 19          136  120  151  151  116  148

# %%
plt.figure(figsize=(20,10))
plt.imshow(grid)
plt.colorbar()
