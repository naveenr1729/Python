# %% [markdown]
# <h1 align="center"><font color="#fffff7">Introduction to Seaborn</h1>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.simplefilter("ignore")

# %% [markdown]
# ### Refer to the official <a href="https://seaborn.pydata.org/tutorial.html">documentation for Seaborn</a> here.

# %% [markdown]
# # Seaborn
# * Better Aesthetics.
# * More Graphs Included.
# * Provides a layer of abstraction hence simple to use.

# %% [markdown]
# # Main Classification
# * Relational Plot
# * Distribution Plot
# * Categorical Plot
# * Regression Plot
# * Matrix PLot
# * Multiplots

# %% [markdown]
# # 1) Relational Plot
# * To see the statistical relation between 2 or more variables.
# * Used for bivariate analysis

# %% [markdown]
# # Scatterplot

# %%
d1=pd.read_csv(r"D:\Python\Datasets\tips.csv")
d1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# scatterplot is an axis level function
sns.scatterplot(data=d1,x="total_bill",y="tip",hue="sex",style="time")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# * **hue:** You can use the hue parameter to color the points in the plot according to a variable in the dataset. This is useful for adding a third dimension of information to the plot.
#
# * **size:** This parameter allows you to vary the size of the points in the plot based on a variable in the dataset, adding yet another dimension of information.

# %%
# relplot-> figure level -> square shape
sns.relplot(data=d1,x="total_bill",y="tip",kind="scatter",hue="smoker",size="size")

# %% [markdown]
# **style:** You can use the style parameter to differentiate the points using different markers or line styles based on a variable in the dataset.

# %%
sns.relplot(data=d1,x="total_bill",y="tip",hue="sex",style="time",size="size")

# %% [markdown]
# **Sizes:** The sizes parameter allows you to control the size of the points in a scatter plot based on a variable in your dataset

# %%
sns.relplot(data=d1,x="total_bill",y="tip",hue="sex",style="time",size="size",sizes=(15,200))

# %% [markdown]
# # Lineplot

# %%
d2=pd.read_csv(r"D:\Python\Datasets\gapminder_data_graphs.csv")
d2
# Out:
#           country continent  year  life_exp  hdi_index  co2_consump     gdp  \
# 0     Afghanistan      Asia  1998      53.3      0.344       0.0522     NaN
# 1     Afghanistan      Asia  1999      54.7      0.348       0.0402     NaN
# 2     Afghanistan      Asia  2000      54.7      0.350       0.0370     NaN
# 3     Afghanistan      Asia  2001      54.8      0.353       0.0376     NaN
# 4     Afghanistan      Asia  2002      55.5      0.384       0.0471   333.0
# ...           ...       ...   ...       ...        ...          ...     ...
# 3670     Zimbabwe    Africa  2014      58.0      0.547       0.8810  1440.0
# 3671     Zimbabwe    Africa  2015      58.6      0.553       0.8810  1450.0
# 3672     Zimbabwe    Africa  2016      59.2      0.558       0.7710  1430.0
# 3673     Zimbabwe    Africa  2017      59.9      0.563       0.8450  1480.0
# 3674     Zimbabwe    Africa  2018      60.6      0.569       0.8500  1510.0
#
#       services
# 0         24.4
# 1         24.6
# ...

# %%
d2_india=d2[d2["country"]=="India"]
d2_india
# Out:
#      country continent  year  life_exp  hdi_index  co2_consump     gdp  \
# 1512   India      Asia  1998      62.1      0.481        0.916   695.0
# 1513   India      Asia  1999      62.6      0.489        0.960   743.0
# 1514   India      Asia  2000      62.9      0.495        0.975   758.0
# 1515   India      Asia  2001      63.3      0.499        0.964   781.0
# 1516   India      Asia  2002      63.8      0.506        0.959   797.0
# 1517   India      Asia  2003      64.5      0.518        0.983   845.0
# 1518   India      Asia  2004      65.2      0.527        1.010   898.0
# 1519   India      Asia  2005      65.4      0.536        1.060   954.0
# 1520   India      Asia  2006      65.6      0.546        1.110  1010.0
# 1521   India      Asia  2007      65.8      0.555        1.180  1080.0
# 1522   India      Asia  2008      66.1      0.563        1.290  1090.0
# 1523   India      Asia  2009      66.8      0.569        1.410  1160.0
# ...

# %%
# Axis level
sns.lineplot(data=d2_india,x="year",y="life_exp")
# Out:
# <Axes: xlabel='year', ylabel='life_exp'>

# %%
# figure level
sns.relplot(data=d2_india,x="year",y="life_exp",kind="line")

# %%
d2_c=d2[d2["country"].isin(["India","Pakistan","China"])]
d2_c
# Out:
#        country continent  year  life_exp  hdi_index  co2_consump     gdp  \
# 693      China      Asia  1998      70.9      0.571        2.570  1910.0
# 694      China      Asia  1999      71.2      0.579        2.540  2040.0
# 695      China      Asia  2000      71.3      0.588        2.600  2190.0
# 696      China      Asia  2001      71.7      0.596        2.640  2360.0
# 697      China      Asia  2002      72.0      0.606        2.900  2560.0
# ...        ...       ...   ...       ...        ...          ...     ...
# 2515  Pakistan      Asia  2014      64.2      0.530        0.915  1320.0
# 2516  Pakistan      Asia  2015      64.4      0.536        0.926  1360.0
# 2517  Pakistan      Asia  2016      64.7      0.542        0.967  1400.0
# 2518  Pakistan      Asia  2017      64.9      0.550        1.020  1450.0
# 2519  Pakistan      Asia  2018      65.5      0.552        1.050  1500.0
#
#       services
# 693       26.7
# 694       26.9
# 695       27.5
# 696       27.7
# ...

# %%
sns.relplot(data=d2_c,x="year",y="life_exp",kind="line",hue="country")

# %%
d3_d=d2[d2["country"].isin(["India","Nigeria","Brazil"])]
d3_d
# Out:
#       country      continent  year  life_exp  hdi_index  co2_consump     gdp  \
# 441    Brazil  South America  1998      70.4      0.670        1.820  6660.0
# 442    Brazil  South America  1999      70.8      0.676        1.840  6600.0
# 443    Brazil  South America  2000      71.2      0.685        1.860  6790.0
# 444    Brazil  South America  2001      71.5      0.691        1.880  6790.0
# 445    Brazil  South America  2002      71.8      0.699        1.830  6900.0
# ...       ...            ...   ...       ...        ...          ...     ...
# 2431  Nigeria         Africa  2014      61.6      0.523        0.725  2690.0
# 2432  Nigeria         Africa  2015      62.1      0.526        0.627  2690.0
# 2433  Nigeria         Africa  2016      62.7      0.526        0.634  2580.0
# 2434  Nigeria         Africa  2017      63.3      0.531        0.644  2530.0
# 2435  Nigeria         Africa  2018      63.8      0.534        0.650  2510.0
#
#       services
# 441       61.0
# ...

# %%
sns.relplot(data=d3_d,x="year",y="life_exp",hue="country",style="continent",kind="line")

# %%
sns.relplot(data=d3_d,x="year",y="life_exp",hue="country",style="continent",kind="line",size="continent")

# %% [markdown]
# # Facet Plot - Same plots as subplots

# %% [markdown]
# Facet plot will only work with figure level plots.

# %%
sns.relplot(data=d1,x="total_bill",y="tip",kind="scatter",col="sex")

# %%
sns.relplot(data=d1,x="total_bill",y="tip",kind="scatter",row="smoker")

# %%
sns.relplot(data=d1,x="total_bill",y="tip",kind="scatter",col="sex",row="day")

# %%
sns.relplot(data=d2,x="life_exp",y="gdp",kind="scatter",col="year",col_wrap=3)
